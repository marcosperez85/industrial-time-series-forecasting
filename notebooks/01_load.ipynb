# %% [markdown]
# # Cargar y ver dataset

# %%
# Carga de Dataset - Genérico

## Objetivo:
### ✔ Cargar datos usando configuración
### ✔ Inspección inicial automática
### ✔ Validación de estructura

import sys
sys.path.append('../src')

from data_loader import load_raw, get_feature_target_columns
from config_loader import load_config

# Cargar configuración
config = load_config("../config.yaml")  # Especificar ruta relativa
print("📋 Configuración cargada:")
print(f"   Dataset: {config['dataset']['path']}")
print(f"   Columna temporal: {config['dataset']['datetime_col']}")
print(f"   Columna target: {config['dataset']['target_col']}")

# Cargar dataset
df = load_raw("../config.yaml")

# Información básica
print(f"\n📊 INFORMACIÓN DEL DATASET:")
print(f"   Forma: {df.shape}")
print(f"   Memoria: {df.memory_usage().sum() / 1024**2:.1f} MB")

# Primeras filas
print(f"\n🔍 PRIMERAS 5 FILAS:")
display(df.head())

# Información detallada
print(f"\n📈 INFORMACIÓN DETALLADA:")
df.info()

# Obtener columnas según configuración
feature_cols, target_col = get_feature_target_columns("../config.yaml")
print(f"\n🎯 COLUMNAS SEGÚN CONFIGURACIÓN:")
print(f"   Features: {feature_cols}")
print(f"   Target: {target_col}")

# Verificar que las columnas existen
missing_cols = set(feature_cols + [target_col]) - set(df.columns)
if missing_cols:
    print(f"   ⚠️  Columnas faltantes: {missing_cols}")
else:
    print(f"   ✅ Todas las columnas configuradas están presentes")

# Rango temporal
datetime_col = config['dataset']['datetime_col']
print(f"\n📅 RANGO TEMPORAL:")
print(f"   Inicio: {df[datetime_col].min()}")
print(f"   Final: {df[datetime_col].max()}")
print(f"   Duración: {df[datetime_col].max() - df[datetime_col].min()}")

# Valores nulos
print(f"\n🔍 VALORES NULOS:")
null_counts = df.isnull().sum()
if null_counts.sum() == 0:
    print("   ✅ No hay valores nulos")
else:
    print(null_counts[null_counts > 0])
# Out:
# 📋 Configuración cargada:
#    Dataset: data/raw/industrial_timeseries.csv
#    Columna temporal: timestamp
#    Columna target: value
# ✅ Dataset raw cargado desde: ../data/raw/industrial_timeseries.csv
#    Shape: (17520, 10)
#    Columnas: ['timestamp', 'value', 'temperature', 'demand_factor', 'operational_efficiency', 'energy_price', 'hour', 'day_of_week', 'month', 'is_weekend']
#    Rango temporal: 2022-01-01 00:00:00 a 2023-12-31 23:00:00
#
# 📊 INFORMACIÓN DEL DATASET:
#    Forma: (17520, 10)
#    Memoria: 1.3 MB
#
# 🔍 PRIMERAS 5 FILAS:
#             timestamp    value  temperature  demand_factor  \
# 0 2022-01-01 00:00:00  1188.15        20.99         0.5060
# 1 2022-01-01 01:00:00  1211.43        21.80         0.5478
# 2 2022-01-01 02:00:00  1165.22        25.32         0.4807
# 3 2022-01-01 03:00:00  1221.48        28.74         0.6202
# 4 2022-01-01 04:00:00  1186.60        26.50         0.4447
#
#    operational_efficiency  energy_price  hour  day_of_week  month  is_weekend
# 0                  0.8424         81.83     0            5      1           1
# 1                  0.8637         83.15     1            5      1           1
# 2                  0.8237         78.85     2            5      1           1
# 3                  0.8268         93.94     3            5      1           1
# 4                  0.8438         85.12     4            5      1           1
# 📈 INFORMACIÓN DETALLADA:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17520 entries, 0 to 17519
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   timestamp               17520 non-null  datetime64[ns]
#  1   value                   17520 non-null  float64
#  2   temperature             17520 non-null  float64
#  3   demand_factor           17520 non-null  float64
#  4   operational_efficiency  17520 non-null  float64
#  5   energy_price            17520 non-null  float64
#  6   hour                    17520 non-null  int64
#  7   day_of_week             17520 non-null  int64
#  8   month                   17520 non-null  int64
#  9   is_weekend              17520 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(4)
# memory usage: 1.3 MB
#
# 🎯 COLUMNAS SEGÚN CONFIGURACIÓN:
#    Features: ['temperature', 'demand_factor', 'operational_efficiency', 'energy_price']
#    Target: value
#    ✅ Todas las columnas configuradas están presentes
#
# 📅 RANGO TEMPORAL:
#    Inicio: 2022-01-01 00:00:00
#    Final: 2023-12-31 23:00:00
#    Duración: 729 days 23:00:00
#
# 🔍 VALORES NULOS:
#    ✅ No hay valores nulos
