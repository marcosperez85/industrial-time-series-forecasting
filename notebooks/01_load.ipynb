# %% [markdown]
# # Cargar y ver dataset
#
# ## Objetivo:
# ### ✔ entender cómo cargar datos
# ### ✔ ver tipos
# ### ✔ primer vistazo real

# %%
import pandas as pd

df = pd.read_csv("../data/raw/gas_consumption.csv", parse_dates=["date"])

df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            24 non-null     datetime64[ns]
#  1   consumption_m3  24 non-null     int64
#  2   temp            24 non-null     int64
#  3   humidity        24 non-null     int64
#  4   wind            24 non-null     int64
#  5   weekday         24 non-null     int64
# dtypes: datetime64[ns](1), int64(5)
# memory usage: 1.3 KB
